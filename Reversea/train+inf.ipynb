# %%
from transmap import process_images 

process_images(input_dir= "RAW", 
               output_dir= r"Transmap")

# %%
## To train:
# !python3 reversea_uie.py --images "RAW" \
                     --depth "Transmap" \
                     --output "Output" \
                     --checkpoints "Output/check"
# Out:
# Seed: 9006409290487662472
# training
# 100%|█████████████████████████████████████████| 500/500 [00:22<00:00, 22.06it/s]
# 100%|████████████████████████████████████| 500/500 [00:00<00:00, 4017532.57it/s]
# Losses: -0.313184053
# Avg time per eval: 6.466484 ms (6.466479 ms bs, 0.000005 ms at)
# UCIQE: 0.867474205597214
# UQIMS: 2.9125173067707966
# UCIQE: 0.6953165490147428
# UQIMS: 3.3791016291366303
# UCIQE: 0.7131593170000826
# UQIMS: 3.3958755937498815
# UCIQE: 0.550329616015601
# UQIMS: 3.3225679472978156
# UCIQE: 0.5762469602797802
# UQIMS: 3.217354320573123
# UCIQE: 0.5031442330257623
# UQIMS: 3.179330248872642
# UCIQE: 0.6080928877997858
# UQIMS: 3.34597992538815
# Evaluation metrics saved to Output/evaluation_metrics.xlsx

# %%
##  INFERENCE
# !python3 inf.py --images "RAW" \
                     --depth "Transmap" \
                     --output 'Out_inf' \
                     --checkpoints 'Output/check'
